# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.style.use('ggplot')
import seaborn as sns

## matplotlib 그래프에서 한글 깨짐 에러 해결
import matplotlib
from matplotlib import font_manager, rc
import platform

if platform.system() == 'Windows':
# 윈도우인 경우
    font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
else:    
# Mac 인 경우
    rc('font', family='AppleGothic')
    
matplotlib.rcParams['axes.unicode_minus'] = False

# %%
## 제공 데이터 불러오기
df = pd.read_excel('/Users/andrew/hongsu/data/01_제공데이터/2021 빅콘테스트_데이터분석분야_퓨처스리그_홍수ZERO_댐유입량,강우,수위데이터_210803.xlsx', header=[0,1])[:2891]  # 이후부터는 유입량이 없는 데이터

# %%
## 제공 데이터 사이즈
df.shape
# Out:
# (2891, 48)

# %% [markdown]
# <br>
# <br>

# %%
# df column name 정리

new_col = [df.columns[:6][i][0] for i in range(6)]
new_col

new_col2 = [df.columns[6:][i][1] for i in range(42)]
new_col2

col_names = new_col + new_col2

df.columns = col_names

# %%
display(df.head())
display(df.tail())
# Out:
#    홍수사상번호     연  월   일  시간         유입량  유역평균강수  강우(A지역)  강우(B지역)  강우(C지역)  \
# 0       1  2006  7  10   8  189.100000     6.4        7        7        7
# 1       1  2006  7  10   9  216.951962     6.3        7        8        7
# 2       1  2006  7  10  10  251.424419     6.4        7        9        7
# 3       1  2006  7  10  11  302.812199     7.3        7       10        7
# 4       1  2006  7  10  12  384.783406     8.2        7       12        8
#
#    ...  강우(D지역)  수위(E지역)  수위(D지역)  유역평균강수  강우(A지역)  강우(B지역)  강우(C지역)  강우(D지역)  \
# 0  ...        8     2.54  122.660     6.4        7        7        8        8
# 1  ...       10     2.53  122.648     7.3        7        8       10       10
# 2  ...       11     2.53  122.636     8.2        7        9       10       11
# 3  ...       14     2.53  122.620    11.3        9       10       15       14
# 4  ...       16     2.53  122.604    14.4       12       12       18       16
#
#    수위(E지역)  수위(D지역)
# 0     2.54  122.610
# ...

# %% [markdown]
# <br>
# <br>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2891 entries, 0 to 2890
# Data columns (total 48 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   홍수사상번호   2891 non-null   int64
#  1   연        2891 non-null   int64
#  2   월        2891 non-null   int64
#  3   일        2891 non-null   int64
#  4   시간       2891 non-null   int64
#  5   유입량      2891 non-null   float64
#  6   유역평균강수   2891 non-null   float64
#  7   강우(A지역)  2891 non-null   int64
#  8   강우(B지역)  2891 non-null   int64
#  9   강우(C지역)  2891 non-null   int64
#  10  강우(D지역)  2891 non-null   int64
#  11  수위(E지역)  2891 non-null   float64
#  12  수위(D지역)  2891 non-null   float64
#  13  유역평균강수   2891 non-null   float64
#  14  강우(A지역)  2891 non-null   int64
#  15  강우(B지역)  2891 non-null   int64
#  16  강우(C지역)  2891 non-null   int64
#  17  강우(D지역)  2891 non-null   int64
#  18  수위(E지역)  2891 non-null   float64
#  19  수위(D지역)  2891 non-null   float64
# ...

# %%
## 결측치 확인 (결측치 없음)
df.isnull().sum() / len(df) * 100
# Out:
# 홍수사상번호     0.0
# 연          0.0
# 월          0.0
# 일          0.0
# 시간         0.0
# 유입량        0.0
# 유역평균강수     0.0
# 강우(A지역)    0.0
# 강우(B지역)    0.0
# 강우(C지역)    0.0
# 강우(D지역)    0.0
# 수위(E지역)    0.0
# 수위(D지역)    0.0
# 유역평균강수     0.0
# 강우(A지역)    0.0
# 강우(B지역)    0.0
# 강우(C지역)    0.0
# 강우(D지역)    0.0
# 수위(E지역)    0.0
# 수위(D지역)    0.0
# 유역평균강수     0.0
# 강우(A지역)    0.0
# 강우(B지역)    0.0
# 강우(C지역)    0.0
# 강우(D지역)    0.0
# 수위(E지역)    0.0
# 수위(D지역)    0.0
# 유역평균강수     0.0
# 강우(A지역)    0.0
# 강우(B지역)    0.0
# 강우(C지역)    0.0
# 강우(D지역)    0.0
# 수위(E지역)    0.0
# 수위(D지역)    0.0
# 유역평균강수     0.0
# 강우(A지역)    0.0
# 강우(B지역)    0.0
# 강우(C지역)    0.0
# 강우(D지역)    0.0
# 수위(E지역)    0.0
# 수위(D지역)    0.0
# 유역평균강수     0.0
# 강우(A지역)    0.0
# 강우(B지역)    0.0
# 강우(C지역)    0.0
# 강우(D지역)    0.0
# 수위(E지역)    0.0
# 수위(D지역)    0.0
# dtype: float64

# %%
# 결측치 확인 그래프

import missingno as msno
msno.matrix(df, figsize=(20,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <br>
# <br>

# %%
df.iloc[:,5].describe()

# 평균이 약 1747인데 중앙값은 약 1066 정도
# 상위 75%까지의 강수량이 약 2213인데, max는 약 21504
# 어느 시점에 마구 쏟아지는 것 같은 분포(장마철)
# Out:
# count     2891.000000
# mean      1746.902717
# std       2181.790290
# min          3.541153
# 25%        384.762514
# 50%       1065.549253
# 75%       2213.014288
# max      21504.402260
# Name: 유입량, dtype: float64

# %% [markdown]
# <br>

# %%
plt.figure(figsize=(7,5))
pd.DataFrame(df.iloc[:,5]).boxplot(column=['유입량'])
plt.show()
# 유입량이 극단적으로 많은 이상치가 많이 존재

# %%
# 이상치 개수 확인

IQR = df.iloc[:,5].describe()['75%'] - df.iloc[:,5].describe()['25%']
max_value = df.iloc[:,5].describe()['75%'] + 1.5*IQR
min_value = df.iloc[:,5].describe()['25%'] - 1.5*IQR
if min_value <= 0: min_value = 0

print(max_value)
print(min_value)
# Out:
# 4955.391948050001
# 0

# %%
outliers = (df.iloc[:,5] > max_value).sum(axis=0)
print(outliers) # 204개의 이상치 존재
# Out:
# 204

# %% [markdown]
# <br>
# <br>
# <br>

# %%
## df에 year, month, day, time을 이용하여 연간, 월별, 일별, 시간별 유입
figure, ax = plt.subplots(2, 2, figsize=(18,8))

for i in range(1,5):
    plt.subplot(2,2,i)
    sns.boxplot(x=df.iloc[:,i] , y=df.iloc[:,5])

# %% [markdown]
# <ul>
#     <li>2006년에 이상치가 많이 기록. 특히 큰 유입량이 많이 기록된 해이기 때문에 이상치 처리가 필요해 보임</li>
#     <li>2006년과 2008년에 유입량이 많았음</li>
#     <li>7월에 이상치 많이 기록. 대부분 2006년 7월에 기록(10,000 이상은 전부 06년 7월). 다른 해에도 다른 월에 비해 7월에 이상치가 많이 기록됨. 장마철의 영향인 듯.</li>
#     <li>15~17일에 이상치가 많고, 높은 유입량은 25~30일에 많이 기록.</li>
#     <li>시간대에 따른 유입량의 차이는 별로 없어 보임.</li>
# </ul>

# %% [markdown]
# <br>
# <br>

# %%
# 데이터집단 별로 그룹을 나누어 줌
dataGroup = [df.iloc[:,i:i+7] for i in range(6,48,7)]

# %%
## 각 시간대마다 데이터 집단 간의 변수들의 값 중에 이상치를 가지는지 확인(x축은 시간 순으로 정렬된 인덱스)
variables = ['유역평균강수','강우(A지역)','강우(B지역)','강우(C지역)','강우(D지역)','수위(E지역)','수위(D지역)']

for i in range(7):
    plt.figure(figsize=(25, 20))
    data = df[variables[i]]
    data.columns = list(range(1,7))
    data.plot(figsize=(18,6))
    plt.legend(title=variables[i])
plt.show()

# %% [markdown]
# **7개의 변수 모두 6개의 데이터 집단 내에서 비슷한 값을 가짐.**

# %% [markdown]
# <br>
# <br>

# %%
# 6개의 데이터 집단에서 독립변수 간의 상관관계 heatmap

fig, ax = plt.subplots(2,3, figsize=(25,18))

for i in range(6):
    plt.subplot(2,3,i+1)
    corr = dataGroup[i].corr()
    mask = np.triu(np.ones_like(corr, dtype=bool))

    cmap = sns.diverging_palette(230, 20, as_cmap=True)

    sns.heatmap(corr, annot=True, mask=mask, cmap=cmap)

# %% [markdown]
# <ul>
#     <li>강우(B지역)과 유역평균강수 간의 관계가 높음</li>
#     <li>수위(D지역)은 다른 변수와 큰 관계가 없음</li>
# </ul>

# %% [markdown]
# <br>
# <br>

# %%
figure, axes = plt.subplots(7,1,figsize=(10,35))

for i in range(7):
    for j in range(6):
        sns.scatterplot(x=dataGroup[j].iloc[:,i], y=df.iloc[:,5], alpha=0.4,
                        label=j+1, ax=axes[i])
    axes[i].legend()
    axes[i].set_xlabel(dataGroup[j].columns[i])
    axes[i].set_ylabel("유입량")
plt.show()

# %% [markdown]
# **다른 변수들은 유입량과 선형성을 찾기 어려운 반면, 수위(E지역)의 경우 유입량과 상대적으로 매우 뚜렷한 선형 관계를 지닌다.**
